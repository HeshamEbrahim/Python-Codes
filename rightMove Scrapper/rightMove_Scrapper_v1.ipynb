# %% [markdown]
# Import Libraries

# %%
import requests
import numpy as np
from bs4 import BeautifulSoup
import urllib.request
import math 
import cv2
import pytesseract
import re
from time import time
from decimal import ROUND_UP
from math import ceil
import pandas as pd
import sys, os

# %% [markdown]
# User Inputs

# %%
#application_path = os.path.dirname(sys.executable)

URL = input('URL: ')
# userMaxPrice = input('Enter Maximum Price: ')
# priceIterator = input('Price Iterator: ')
# minBedNo = input('Minimum number of bedrooms: ')

userMaxPrice = '650000'
priceIterator = '50000'
minBedNo = '2'

# splits the URL to the relevant area only and ignores all the features selected on the website
beforeURL = URL.split('%')[0] + '%'
afterURL = URL.split('%')[1]
URL = afterURL.split('&')[0]
generatedURL = beforeURL + URL + '&minBedrooms=' + minBedNo
print(generatedURL)
# Out:
# https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E1261&minBedrooms=2

# %% [markdown]
# Get all the property addresses

# %%
# rightmove main URL
### initialise search ### 

allLinks = np.array([])
allLinksCombined = np.array([])
cleanLinks = np.array([])
minPrice = 50000
maxPrice = minPrice + int(priceIterator)

pageIterator = (int(userMaxPrice)-minPrice)/int(priceIterator)
for x in range(int(pageIterator)):
    URL = generatedURL + '&maxPrice=' + str(maxPrice) + '&minPrice=' + str(minPrice)
    page = requests.get(URL)

    # parse search results card
    soup = BeautifulSoup(page.content, "html.parser")
    results = soup.find(id='l-container')

    # index for iterator (remember each page has 24 ads)
    noOfResults = soup.find('div', attrs={'id': 'searchHeader'})
    noOfResults = noOfResults.select('span')[0].text
    noOfResults = re.sub(r',', '', noOfResults)
    noOfResults = ceil(int(noOfResults)/24) # round up to nearest page (note max page no is 42)

    print(noOfResults, " Pages available for min price = ", minPrice, " max price = ", maxPrice)

    i = 0
    all_ids = np.array([])
    for x in range(noOfResults):
        URL = generatedURL + '&maxPrice=' + str(maxPrice) + '&minPrice=' + str(minPrice) + '&sortType=18&index='+ str(i)
        print('Scrapped Page No.', x+1)
        page = requests.get(URL)

        # parse search results card
        soup = BeautifulSoup(page.content, "html.parser")
        results = soup.find(id='l-container')

        # Extract and store ids
        links = results.select('a')
        for card in links:
            ids = card.get('id')
            ids = ids.strip() if ids is not None else ''
            all_ids = np.append(all_ids, ids)

        # clean array and add links
        all_ids = all_ids[all_ids != '']
        cleanIds = np.char.strip(all_ids, 'prop')
        allLinks = np.char.add(cleanIds, '#/?channel=RES_BUY')
        allLinks = np.char.add('https://www.rightmove.co.uk/properties/', allLinks)
    
        i = i + 24

    allLinksCombined = np.append(allLinksCombined, allLinks)
    minPrice = minPrice + int(priceIterator) 
    maxPrice = maxPrice + int(priceIterator) 

# removes empty and repeated links 
cleanLinks = np.char.replace(allLinksCombined, 'https://www.rightmove.co.uk/properties/0#/?channel=RES_BUY', '')
cleanLinks = cleanLinks[cleanLinks != '']
cleanLinks = np.unique(cleanLinks)

print('Number of links acquired: ', len(cleanLinks))
print(cleanLinks)
# Out:
# 0  Pages available for min price =  50000  max price =  100000
# 0  Pages available for min price =  100000  max price =  150000
# 0  Pages available for min price =  150000  max price =  200000
# 1  Pages available for min price =  200000  max price =  250000
# Scrapped Page No. 1
# 1  Pages available for min price =  250000  max price =  300000
# Scrapped Page No. 1
# 1  Pages available for min price =  300000  max price =  350000
# Scrapped Page No. 1
# 1  Pages available for min price =  350000  max price =  400000
# Scrapped Page No. 1
# 2  Pages available for min price =  400000  max price =  450000
# Scrapped Page No. 1
# Scrapped Page No. 2
# 2  Pages available for min price =  450000  max price =  500000
# Scrapped Page No. 1
# Scrapped Page No. 2
# 1  Pages available for min price =  500000  max price =  550000
# Scrapped Page No. 1
# 2  Pages available for min price =  550000  max price =  600000
# Scrapped Page No. 1
# Scrapped Page No. 2
# 1  Pages available for min price =  600000  max price =  650000
# Scrapped Page No. 1
# Number of links acquired:  114
# ['https://www.rightmove.co.uk/properties/110758715#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/114150122#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/115815626#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/116211071#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/116727503#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/118596677#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/120312653#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/120319079#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/120339314#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/120829139#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/121249640#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/121459250#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/121729196#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/121954886#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/122654627#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/124008518#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/124054280#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/124169735#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/124413521#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/124514159#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/124577153#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/124598705#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/124690928#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/124895462#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/125005007#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/125017667#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/125339534#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/125522696#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/125729993#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/125824526#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/125860259#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/125986538#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126019256#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031292#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031304#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031310#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031313#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031316#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031319#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031322#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031325#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031334#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126031337#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126065624#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126168698#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126188963#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126200618#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126300713#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126317591#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126336533#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126556739#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126704489#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126757247#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126765482#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126781541#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126801566#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126821450#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/126932051#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127055405#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127060535#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127244756#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127244759#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127276544#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127309973#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127315046#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127369601#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127376063#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127504595#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127510934#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127605137#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127751156#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127756391#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127820777#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127838492#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127842656#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127864568#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127877678#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127892957#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127932041#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/127941773#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128026550#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128152505#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128202899#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128205992#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128277686#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128302784#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128405279#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128506826#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128516492#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128551736#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128582327#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128587961#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128608469#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128626385#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128684510#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128709752#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128723651#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128737040#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128820443#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128888213#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128938613#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128954351#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128989514#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/128997209#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/129073550#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/129086288#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/129113195#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/85091931#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/85477896#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/85493886#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/85540281#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/85545492#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/85887390#/?channel=RES_BUY'
#  'https://www.rightmove.co.uk/properties/85914537#/?channel=RES_BUY']

# %% [markdown]
# Fishing Properties

# %%
i = 0
counter = 0
all_info = np.array([])
data = np.array([])

for property in cleanLinks:
    start = time()
    ad = requests.get(property)
    soup = BeautifulSoup(ad.content, "html.parser")

    # ensures only freehold properties
    if soup.select('p')[4].text.lower() == 'freehold' or soup.select('p')[6].text.lower() == 'freehold':

        # extract property data
        propertyAddress = soup.select('h1')[0].text
        propertyType = soup.select('p')[0].text
        typeOfProperty = soup.select('p')[1].text
        noOfBeds = soup.select('p')[2].text
        priceLink = soup.body.find('div', attrs={'class': '_1gfnqJ3Vtd1z40MlC0MzXu'})
        price = priceLink.select('span')[0].text
        adDateLink = soup.body.find('div', attrs={'class': '_2nk2x6QhNB1UrxdI5KpvaF'})
        date = re.sub('<div class="_2nk2x6QhNB1UrxdI5KpvaF">', '', str(adDateLink))
        date = re.sub('</div>', '', str(date))
        newIds = re.findall(r'\b\d+\b', str(cleanLinks[i])) # use new property id
        mapLocation = np.char.add('https://www.rightmove.co.uk/properties/', str(newIds[0]))
        floorPlan = np.char.add(mapLocation, '#/floorplan?activePlan=1&channel=RES_BUY')
        mapLocation = np.char.add(mapLocation, '#/map?channel=RES_BUY')
        
        # filter through the images to find the floor plan link
        floorPlanImage = requests.get(floorPlan)
        floorPlanImage = BeautifulSoup(floorPlanImage.content, "html.parser")
        floorPlanImage = floorPlanImage.find('div', attrs={'id': 'root'})
        for j in range(len(floorPlanImage.select('img'))):
            nextFloorPlanImage = floorPlanImage.select('img')[j].get_attribute_list('src',str)
            nextFloorPlanImage = ' '.join(nextFloorPlanImage)
            if '_max_296x197' in nextFloorPlanImage:
                foundFloorPlanImage = nextFloorPlanImage.replace('_max_296x197', '')
                break
            else:
                foundFloorPlanImage = 'None'
                pass
        
        i = i+1
        end = time()
        print(str(i)+' out of '+str(len(cleanLinks))+f' It took {round(end - start,2)} seconds!') 

        data = [str(price), str(propertyAddress), str(typeOfProperty), str(noOfBeds), str(foundFloorPlanImage), str(mapLocation), str(date)]
        all_info = np.append(all_info, data)
        counter = counter + 1
    else:
        #print('skipped...')
        i = i+1
        end = time()
        print(str(i)+' out of '+str(len(cleanLinks))+f' It took {round(end - start,2)} seconds!') 
        continue

# split the array into equally divided arrays
all_info = np.split(all_info, counter)
print(all_info)
# Out:
# 1 out of 114 It took 0.43 seconds!
# 2 out of 114 It took 0.43 seconds!
# 3 out of 114 It took 0.65 seconds!
# 4 out of 114 It took 0.86 seconds!
# 5 out of 114 It took 0.39 seconds!
# 6 out of 114 It took 0.52 seconds!
# 7 out of 114 It took 0.4 seconds!
# 8 out of 114 It took 1.61 seconds!
# 9 out of 114 It took 0.36 seconds!
# 10 out of 114 It took 0.37 seconds!
# 11 out of 114 It took 0.54 seconds!
# 12 out of 114 It took 0.72 seconds!
# 13 out of 114 It took 0.4 seconds!
# 14 out of 114 It took 1.5 seconds!
# 15 out of 114 It took 0.38 seconds!
# 16 out of 114 It took 0.4 seconds!
# 17 out of 114 It took 0.84 seconds!
# 18 out of 114 It took 0.53 seconds!
# 19 out of 114 It took 0.77 seconds!
# 20 out of 114 It took 1.46 seconds!
# 21 out of 114 It took 0.35 seconds!
# 22 out of 114 It took 0.75 seconds!
# 23 out of 114 It took 0.42 seconds!
# 24 out of 114 It took 1.49 seconds!
# 25 out of 114 It took 1.67 seconds!
# 26 out of 114 It took 0.82 seconds!
# 27 out of 114 It took 0.41 seconds!
# 28 out of 114 It took 0.38 seconds!
# 29 out of 114 It took 0.37 seconds!
# 30 out of 114 It took 1.93 seconds!
# 31 out of 114 It took 1.45 seconds!
# 32 out of 114 It took 0.38 seconds!
# 33 out of 114 It took 0.97 seconds!
# 34 out of 114 It took 0.75 seconds!
# 35 out of 114 It took 0.37 seconds!
# 36 out of 114 It took 0.42 seconds!
# 37 out of 114 It took 0.38 seconds!
# 38 out of 114 It took 0.36 seconds!
# 39 out of 114 It took 0.34 seconds!
# 40 out of 114 It took 0.55 seconds!
# 41 out of 114 It took 0.4 seconds!
# 42 out of 114 It took 0.45 seconds!
# 43 out of 114 It took 1.49 seconds!
# 44 out of 114 It took 0.4 seconds!
# 45 out of 114 It took 0.53 seconds!
# 46 out of 114 It took 0.41 seconds!
# 47 out of 114 It took 0.36 seconds!
# 48 out of 114 It took 0.37 seconds!
# 49 out of 114 It took 0.51 seconds!
# 50 out of 114 It took 1.99 seconds!
# 51 out of 114 It took 0.36 seconds!
# 52 out of 114 It took 0.37 seconds!
# 53 out of 114 It took 0.39 seconds!
# 54 out of 114 It took 0.39 seconds!
# 55 out of 114 It took 0.83 seconds!
# 56 out of 114 It took 0.58 seconds!
# 57 out of 114 It took 1.94 seconds!
# 58 out of 114 It took 0.41 seconds!
# 59 out of 114 It took 1.54 seconds!
# 60 out of 114 It took 0.8 seconds!
# 61 out of 114 It took 0.39 seconds!
# 62 out of 114 It took 0.38 seconds!
# 63 out of 114 It took 0.58 seconds!
# 64 out of 114 It took 1.51 seconds!
# 65 out of 114 It took 3.08 seconds!
# 66 out of 114 It took 0.39 seconds!
# 67 out of 114 It took 1.6 seconds!
# 68 out of 114 It took 0.37 seconds!
# 69 out of 114 It took 1.51 seconds!
# 70 out of 114 It took 0.38 seconds!
# 71 out of 114 It took 0.39 seconds!
# 72 out of 114 It took 0.52 seconds!
# 73 out of 114 It took 0.37 seconds!
# 74 out of 114 It took 0.71 seconds!
# 75 out of 114 It took 1.52 seconds!
# 76 out of 114 It took 0.4 seconds!
# 77 out of 114 It took 0.36 seconds!
# 78 out of 114 It took 0.73 seconds!
# 79 out of 114 It took 1.14 seconds!
# 80 out of 114 It took 0.65 seconds!
# 81 out of 114 It took 0.95 seconds!
# 82 out of 114 It took 0.73 seconds!
# 83 out of 114 It took 0.75 seconds!
# 84 out of 114 It took 2.07 seconds!
# 85 out of 114 It took 0.4 seconds!
# 86 out of 114 It took 0.42 seconds!
# 87 out of 114 It took 0.48 seconds!
# 88 out of 114 It took 0.42 seconds!
# 89 out of 114 It took 0.36 seconds!
# 90 out of 114 It took 0.46 seconds!
# 91 out of 114 It took 1.39 seconds!
# 92 out of 114 It took 0.39 seconds!
# 93 out of 114 It took 0.4 seconds!
# 94 out of 114 It took 0.34 seconds!
# 95 out of 114 It took 0.8 seconds!
# 96 out of 114 It took 1.5 seconds!
# 97 out of 114 It took 0.94 seconds!
# 98 out of 114 It took 0.56 seconds!
# 99 out of 114 It took 0.43 seconds!
# 100 out of 114 It took 1.5 seconds!
# 101 out of 114 It took 0.36 seconds!
# 102 out of 114 It took 1.49 seconds!
# 103 out of 114 It took 0.39 seconds!
# 104 out of 114 It took 0.34 seconds!
# 105 out of 114 It took 0.37 seconds!
# 106 out of 114 It took 0.33 seconds!
# 107 out of 114 It took 1.3 seconds!
# 108 out of 114 It took 0.38 seconds!
# 109 out of 114 It took 0.43 seconds!
# 110 out of 114 It took 0.35 seconds!
# 111 out of 114 It took 0.36 seconds!
# 112 out of 114 It took 1.48 seconds!
# 113 out of 114 It took 1.5 seconds!
# 114 out of 114 It took 0.52 seconds!
# [array(['£575,000', 'Curzon Avenue, Stanmore, HA7', 'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/46k/45962/116211071/45962_STN180121_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/116211071#/map?channel=RES_BUY',
#        'Reduced on 18/10/2022'], dtype='<U104'), array(['£650,000', 'Stanmore, Middlesex', 'Terraced', '×4',
#        'https://media.rightmove.co.uk/dir/215k/214967/121459250/214967_ZRichardZeffKW0000613313_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/121459250#/map?channel=RES_BUY',
#        'Added on 11/11/2022'], dtype='<U104'), array(['£595,000', 'Daventer Drive, Stanmore, HA7', 'Link Detached House',
#        '×3',
#        'https://media.rightmove.co.uk/dir/44k/43260/124054280/43260_SMO220014_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/124054280#/map?channel=RES_BUY',
#        'Reduced on 06/10/2022'], dtype='<U104'), array(['£585,000', 'Bellamy Drive, Stanmore, Middlesex, HA7',
#        'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/173k/172868/124413521/172868_STN220282_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/124413521#/map?channel=RES_BUY',
#        'Added on 28/06/2022'], dtype='<U104'), array(['£600,000', 'Kenmore Avenue, Harrow', 'Semi-Detached', '×5',
#        'None',
#        'https://www.rightmove.co.uk/properties/124598705#/map?channel=RES_BUY',
#        'Reduced on 31/10/2022'], dtype='<U104'), array(['£650,000', 'St. Edmunds Drive, Stanmore, HA7', 'Semi-Detached',
#        '×5',
#        'https://media.rightmove.co.uk/dir/239k/238889/125017667/238889_31649462_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/125017667#/map?channel=RES_BUY',
#        'Reduced on 30/09/2022'], dtype='<U104'), array(['£585,000', 'Stanmore, Middlesex, HA7', 'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/31k/30482/125824526/30482_4571780_FLP_00_0000.png',
#        'https://www.rightmove.co.uk/properties/125824526#/map?channel=RES_BUY',
#        'Added on 29/06/2022'], dtype='<U104'), array(['£650,000', 'Eaton Close, Stanmore, HA7', 'Terraced', '×4',
#        'https://media.rightmove.co.uk/dir/203k/202922/126019256/202922_1394968-1_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/126019256#/map?channel=RES_BUY',
#        'Added on 12/08/2022'], dtype='<U104'), array(['£600,000', 'Brightwen Grove, Stanmore, HA7', 'Semi-Detached',
#        '×3',
#        'https://media.rightmove.co.uk/dir/251k/250739/126031292/250739_1211080_FLP_02_0000.png',
#        'https://www.rightmove.co.uk/properties/126031292#/map?channel=RES_BUY',
#        'Reduced on 09/08/2022'], dtype='<U104'), array(['£585,000', 'Ashdale Grove, Stanmore, HA7', 'Bungalow', '×2',
#        'https://media.rightmove.co.uk/dir/46k/45479/126336533/45479_EDG220094_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/126336533#/map?channel=RES_BUY',
#        'Added on 23/08/2022'], dtype='<U104'), array(['£565,000', 'Castellane Close, Stanmore, HA7',
#        'Link Detached House', '×3',
#        'https://media.rightmove.co.uk/dir/239k/238889/126781541/238889_31774496_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/126781541#/map?channel=RES_BUY',
#        'Added on 06/09/2022'], dtype='<U104'), array(['£530,000', 'Taunton Way, Stanmore, Middlesex, HA7',
#        'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/173k/172868/126821450/172868_STN220311_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/126821450#/map?channel=RES_BUY',
#        'Added on 07/09/2022'], dtype='<U104'), array(['£549,950', 'Courtens Mews, Stanmore, Middlesex, HA7',
#        'End of Terrace', '×3',
#        'https://media.rightmove.co.uk/dir/173k/172868/127060535/172868_STN220369_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/127060535#/map?channel=RES_BUY',
#        'Reduced on 21/10/2022'], dtype='<U104'), array(['£629,950', 'Charmian Avenue, Stanmore, Middlesex, HA7',
#        'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/173k/172868/127315046/172868_STN220390_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/127315046#/map?channel=RES_BUY',
#        'Reduced yesterday'], dtype='<U104'), array(['£649,950', 'Portland Crescent, Stanmore, HA7', 'Semi-Detached',
#        '×3',
#        'https://media.rightmove.co.uk/dir/235k/234920/127838492/234920_ANDER_002894_FLP_00_0001.jpeg',
#        'https://www.rightmove.co.uk/properties/127838492#/map?channel=RES_BUY',
#        'Added on 07/10/2022'], dtype='<U104'), array(['£575,000', 'Clydesdale Avenue, Stanmore, Middlesex, HA7',
#        'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/173k/172868/127892957/172868_STN220283_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/127892957#/map?channel=RES_BUY',
#        'Reduced on 25/10/2022'], dtype='<U104'), array(['£640,000', 'Woodlands Drive, Stanmore, HA7', 'House', '×3',
#        'https://media.rightmove.co.uk/dir/251k/250739/127932041/250739_1215037_FLP_00_0000.png',
#        'https://www.rightmove.co.uk/properties/127932041#/map?channel=RES_BUY',
#        'Reduced on 31/10/2022'], dtype='<U104'), array(['£649,950', 'Portland Crescent, Stanmore, Middlesex, HA7',
#        'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/7k/6292/128026550/6292_KTN220030_FLP_00_0000.png',
#        'https://www.rightmove.co.uk/properties/128026550#/map?channel=RES_BUY',
#        'Added on 14/10/2022'], dtype='<U104'), array(['£585,000', 'Bellamy Drive, Stanmore', 'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/12k/11525/128152505/11525_0169_HRT016910765_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/128152505#/map?channel=RES_BUY',
#        'Added on 29/06/2022'], dtype='<U104'), array(['£595,000', 'Dean Drive, Stanmore, HA7', 'End of Terrace', '×3',
#        'https://media.rightmove.co.uk/dir/251k/250739/128202899/250739_1218529_FLP_00_0000.png',
#        'https://www.rightmove.co.uk/properties/128202899#/map?channel=RES_BUY',
#        'Reduced on 31/10/2022'], dtype='<U104'), array(['£650,000', 'Courtens Mews, Stanmore, London, HA7',
#        'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/173k/172868/128205992/172868_STN210254_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/128205992#/map?channel=RES_BUY',
#        'Added on 19/10/2022'], dtype='<U104'), array(['£550,000', 'Acacia Close, Stanmore', 'Town House', '×4',
#        'https://media.rightmove.co.uk/dir/12k/11525/128582327/11525_0169_HRT016910677_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/128582327#/map?channel=RES_BUY',
#        'Added on 17/08/2022'], dtype='<U104'), array(['£599,999', 'Derwent Crescent, Stanmore, HA7', 'House', '×3',
#        'https://media.rightmove.co.uk/dir/239k/238889/128684510/238889_31919476_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/128684510#/map?channel=RES_BUY',
#        'Added on 03/11/2022'], dtype='<U104'), array(['£600,000', 'Broadcroft Avenue, Stanmore, HA7', 'Semi-Detached',
#        '×3',
#        'https://media.rightmove.co.uk/dir/44k/43260/128723651/43260_SMO220229_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/128723651#/map?channel=RES_BUY',
#        'Added on 03/11/2022'], dtype='<U104'), array(['£600,000', 'Woodstock Close, Stanmore', 'Semi-Detached', '×3',
#        'https://media.rightmove.co.uk/dir/12k/11525/129113195/11525_0169_HRT016910628_FLP_00_0000.jpeg',
#        'https://www.rightmove.co.uk/properties/129113195#/map?channel=RES_BUY',
#        'Added on 15/10/2022'], dtype='<U104')]

# %% [markdown]
# Image Processing

# %%
import importlib 
from numpy import empty
import searchFunction
importlib.reload(searchFunction) # forces the definition to reload in case you make changes to it
from searchFunction import search 

updated_info = np.array([])

for info in range(len(all_info)):
    print(str(info+1)+' out of '+str(len(all_info)))
    try:
        if not all_info[info][4] == 'None':
            # Load the img
            req = urllib.request.urlopen(all_info[info][4])
            arr = np.asarray(bytearray(req.read()))
            img = cv2.imdecode(arr, -1) # 'Load it as it is'

            # Display loaded image
            # cv2.imshow('Floor Plan', img)
            # if cv2.waitKey() & 0xff == 27: quit()

            # OCR
            pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
            configs = r'--psm 6'
            try:
                rawText = pytesseract.image_to_string(img, config=configs)
            except:
                continue
            rawText = rawText.lower()
            rawText = re.sub(r',', '', str(rawText)) # removes all commas 
            rawText = re.sub(r'\b\.\d+\b', '', str(rawText)) # removes all ints
            #print(rawText)

            newText = search(rawText)
            #print(newText)
            newInfo = list(np.append(all_info[info], newText)) # adding list adds the ',' back into the string array    
            updated_info = np.append(updated_info, newInfo)
    except:
        continue        

# split the array into equally divided arrays and convert to pandas for further processing
updated_info = np.split(updated_info, len(updated_info)/8) 
updated_info = pd.DataFrame(updated_info, columns = ['price', 'propertyAddress', 'typeOfProperty', 'noOfBeds', 'foundFloorPlanImage', 'mapLocation', 'date', 'area'])
updated_info = updated_info.drop(columns='foundFloorPlanImage')
print(updated_info)
# Out:
# 1 out of 25
# 2 out of 25
# 3 out of 25
# 4 out of 25
# 5 out of 25
# 6 out of 25
# 7 out of 25
# 8 out of 25
# 9 out of 25
# 10 out of 25
# 11 out of 25
# 12 out of 25
# 13 out of 25
# 14 out of 25
# 15 out of 25
# 16 out of 25
# 17 out of 25
# 18 out of 25
# 19 out of 25
# 20 out of 25
# 21 out of 25
# 22 out of 25
# 23 out of 25
# 24 out of 25
# 25 out of 25
#        price                              propertyAddress  \
# 0   £575,000                 Curzon Avenue, Stanmore, HA7
# 1   £650,000                          Stanmore, Middlesex
# 2   £595,000                Daventer Drive, Stanmore, HA7
# 3   £585,000      Bellamy Drive, Stanmore, Middlesex, HA7
# 4   £650,000             St. Edmunds Drive, Stanmore, HA7
# 5   £585,000                     Stanmore, Middlesex, HA7
# 6   £650,000                   Eaton Close, Stanmore, HA7
# 7   £600,000               Brightwen Grove, Stanmore, HA7
# 8   £585,000                 Ashdale Grove, Stanmore, HA7
# 9   £565,000              Castellane Close, Stanmore, HA7
# 10  £530,000        Taunton Way, Stanmore, Middlesex, HA7
# 11  £549,950      Courtens Mews, Stanmore, Middlesex, HA7
# 12  £629,950    Charmian Avenue, Stanmore, Middlesex, HA7
# 13  £649,950             Portland Crescent, Stanmore, HA7
# 14  £575,000  Clydesdale Avenue, Stanmore, Middlesex, HA7
# 15  £640,000               Woodlands Drive, Stanmore, HA7
# 16  £649,950  Portland Crescent, Stanmore, Middlesex, HA7
# 17  £585,000                      Bellamy Drive, Stanmore
# 18  £595,000                    Dean Drive, Stanmore, HA7
# 19  £650,000         Courtens Mews, Stanmore, London, HA7
# 20  £550,000                       Acacia Close, Stanmore
# 21  £599,999              Derwent Crescent, Stanmore, HA7
# 22  £600,000             Broadcroft Avenue, Stanmore, HA7
# 23  £600,000                    Woodstock Close, Stanmore
#
#          typeOfProperty noOfBeds  \
# 0         Semi-Detached       ×3
# 1              Terraced       ×4
# 2   Link Detached House       ×3
# 3         Semi-Detached       ×3
# 4         Semi-Detached       ×5
# 5         Semi-Detached       ×3
# 6              Terraced       ×4
# 7         Semi-Detached       ×3
# 8              Bungalow       ×2
# 9   Link Detached House       ×3
# 10        Semi-Detached       ×3
# 11       End of Terrace       ×3
# 12        Semi-Detached       ×3
# 13        Semi-Detached       ×3
# 14        Semi-Detached       ×3
# 15                House       ×3
# 16        Semi-Detached       ×3
# 17        Semi-Detached       ×3
# 18       End of Terrace       ×3
# 19        Semi-Detached       ×3
# 20           Town House       ×4
# 21                House       ×3
# 22        Semi-Detached       ×3
# 23        Semi-Detached       ×3
#
#                                           mapLocation                   date  \
# 0   https://www.rightmove.co.uk/properties/1162110...  Reduced on 18/10/2022
# 1   https://www.rightmove.co.uk/properties/1214592...    Added on 11/11/2022
# 2   https://www.rightmove.co.uk/properties/1240542...  Reduced on 06/10/2022
# 3   https://www.rightmove.co.uk/properties/1244135...    Added on 28/06/2022
# 4   https://www.rightmove.co.uk/properties/1250176...  Reduced on 30/09/2022
# 5   https://www.rightmove.co.uk/properties/1258245...    Added on 29/06/2022
# 6   https://www.rightmove.co.uk/properties/1260192...    Added on 12/08/2022
# 7   https://www.rightmove.co.uk/properties/1260312...  Reduced on 09/08/2022
# 8   https://www.rightmove.co.uk/properties/1263365...    Added on 23/08/2022
# 9   https://www.rightmove.co.uk/properties/1267815...    Added on 06/09/2022
# 10  https://www.rightmove.co.uk/properties/1268214...    Added on 07/09/2022
# 11  https://www.rightmove.co.uk/properties/1270605...  Reduced on 21/10/2022
# 12  https://www.rightmove.co.uk/properties/1273150...      Reduced yesterday
# 13  https://www.rightmove.co.uk/properties/1278384...    Added on 07/10/2022
# 14  https://www.rightmove.co.uk/properties/1278929...  Reduced on 25/10/2022
# 15  https://www.rightmove.co.uk/properties/1279320...  Reduced on 31/10/2022
# 16  https://www.rightmove.co.uk/properties/1280265...    Added on 14/10/2022
# 17  https://www.rightmove.co.uk/properties/1281525...    Added on 29/06/2022
# 18  https://www.rightmove.co.uk/properties/1282028...  Reduced on 31/10/2022
# 19  https://www.rightmove.co.uk/properties/1282059...    Added on 19/10/2022
# 20  https://www.rightmove.co.uk/properties/1285823...    Added on 17/08/2022
# 21  https://www.rightmove.co.uk/properties/1286845...    Added on 03/11/2022
# 22  https://www.rightmove.co.uk/properties/1287236...    Added on 03/11/2022
# 23  https://www.rightmove.co.uk/properties/1291131...    Added on 15/10/2022
#
#     area
# 0   1018
# 1   1382
# 2    917
# 3    955
# 4   1370
# 5   1111
# 6   1010
# 7    873
# 8    642
# 9    905
# 10   655
# 11   878
# 12  1329
# 13  1076
# 14  1230
# 15  1369
# 16   943
# 17   513
# 18   881
# 19   875
# 20     0
# 21   878
# 22  1056
# 23   393

# %%
# this should load the old file and append any new data found to it making sure it's all unique data
# and not repeated 

updated_info.to_csv('output.csv', index=False) # comment out if you want to use the old data

loadData = pd.read_csv(r'output.csv')
frames = [loadData, updated_info]
combinedData = pd.concat(frames)
combinedData = combinedData.drop_duplicates(subset=['mapLocation'])

combinedData['price'] = combinedData['price'].replace('[\£,]', '', regex=True).astype(float)
combinedData['area'] = combinedData['area'].astype(float)
combinedData['priceRank'] = combinedData['price'].rank(ascending=1)
combinedData['areaRank'] = combinedData['area'].rank(ascending=0)
combinedData['Rank Sum'] = combinedData.priceRank + combinedData.areaRank
combinedData = combinedData.sort_values(by = 'Rank Sum', ascending = True)

combinedData.to_csv('output_processed.csv', index=False)
print(combinedData)
# Out:
#        price                                 propertyAddress  typeOfProperty  \
# 2   750000.0                         Manger Road, London, N7           House
# 3   525000.0  Laffitte House, New Orleans Walk, Hornsey Rise       Apartment
# 12  630000.0                       Parkside Crescent, London        Terraced
# 4   750000.0                             Blackstock Road, N4        Terraced
# 15  750000.0                         Russet Crescent, London  End of Terrace
# 11  750000.0                     Russet Crescent, London, N7  End of Terrace
# 5   750000.0          Russet Crescent, Islington, London, N7           House
# 9   500000.0                         Tollington Park, London       Apartment
# 6   600000.0                    Fonthill Road, Finsbury Park        Terraced
# 10  800000.0                   Pavillion Mews, Finsbury Park        Terraced
# 13  475000.0                         Burder Road, London, N1            Flat
# 8   675000.0                  Mildmay Grove South, Islington            Flat
# 16  725000.0                               City Road, London            Flat
# 7   800000.0           New North Road, Islington, London, N1        Terraced
# 1   750000.0    Pemberton Gardens, Tufnell Park, London, N19            Flat
# 0   775000.0    Pemberton Gardens, Tufnell Park, London, N19            Flat
# 14  750000.0                   Conewood Street, Highbury, N5  End of Terrace
# 17  800000.0                    Fairbridge Road, London, N19        Terraced
#
#    noOfBeds                                foundFloorPlanImage  \
# 2        ×4  https://media.rightmove.co.uk/dir/38k/37916/11...
# 3        ×3  https://media.rightmove.co.uk/dir/32k/31274/12...
# 12       ×3  https://media.rightmove.co.uk/dir/209k/208337/...
# 4        ×3  https://media.rightmove.co.uk/dir/177k/176261/...
# 15       ×4  https://media.rightmove.co.uk/dir/205k/204362/...
# 11       ×4  https://media.rightmove.co.uk/dir/80k/79570/12...
# 5        ×4  https://media.rightmove.co.uk/dir/16k/15954/12...
# 9        ×2  https://media.rightmove.co.uk/dir/15k/14497/12...
# 6        ×2  https://media.rightmove.co.uk/dir/19k/18933/12...
# 10       ×3  https://media.rightmove.co.uk/dir/23k/22559/12...
# 13       ×2  https://media.rightmove.co.uk/dir/127k/126928/...
# 8        ×2  https://media.rightmove.co.uk/dir/119k/118693/...
# 16       ×2  https://media.rightmove.co.uk/dir/205k/204362/...
# 7        ×4  https://media.rightmove.co.uk/dir/35k/34986/12...
# 1        ×3  https://media.rightmove.co.uk/dir/65k/64127/10...
# 0        ×3  https://media.rightmove.co.uk/dir/65k/64127/10...
# 14       ×2  https://media.rightmove.co.uk/dir/53k/52785/12...
# 17       ×4  https://media.rightmove.co.uk/dir/70k/69289/85...
#
#                                           mapLocation    area  priceRank  \
# 2   https://www.rightmove.co.uk/properties/1150203...  1557.0       11.0
# 3   https://www.rightmove.co.uk/properties/1201190...   903.0        3.0
# 12  https://www.rightmove.co.uk/properties/1275552...   949.0        5.0
# 4   https://www.rightmove.co.uk/properties/1239055...  1139.0       11.0
# 15  https://www.rightmove.co.uk/properties/1283792...  1055.0       11.0
# 11  https://www.rightmove.co.uk/properties/1268786...  1051.0       11.0
# 5   https://www.rightmove.co.uk/properties/1252150...  1043.0       11.0
# 9   https://www.rightmove.co.uk/properties/1261655...   637.0        2.0
# 6   https://www.rightmove.co.uk/properties/1256407...   681.0        4.0
# 10  https://www.rightmove.co.uk/properties/1264313...  1229.0       17.0
# 13  https://www.rightmove.co.uk/properties/1276967...   421.0        1.0
# 8   https://www.rightmove.co.uk/properties/1260733...   722.0        6.0
# 16  https://www.rightmove.co.uk/properties/1284857...   743.0        7.0
# 7   https://www.rightmove.co.uk/properties/1259048...  1139.0       17.0
# 1   https://www.rightmove.co.uk/properties/1098286...   917.0       11.0
# 0   https://www.rightmove.co.uk/properties/1098017...  1028.0       15.0
# 14  https://www.rightmove.co.uk/properties/1280482...   793.0       11.0
# 17  https://www.rightmove.co.uk/properties/8551439...   541.0       17.0
#
#     areaRank  Rank Sum
# 2        1.0      12.0
# 3       11.0      14.0
# 12       9.0      14.0
# 4        3.5      14.5
# 15       5.0      16.0
# 11       6.0      17.0
# 5        7.0      18.0
# 9       16.0      18.0
# 6       15.0      19.0
# 10       2.0      19.0
# 13      18.0      19.0
# 8       14.0      20.0
# 16      13.0      20.0
# 7        3.5      20.5
# 1       10.0      21.0
# 0        8.0      23.0
# 14      12.0      23.0
# 17      17.0      34.0
